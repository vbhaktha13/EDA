# %% [markdown]
# <p align="center"><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="260" height="110" /></p>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# 1. [**Introduction**](#Section1)<br>
# 2. [**Problem Statement**](#Section2)<br>
# 3. [**Installing & Importing Libraries**](#Section3)<br>
#   3.1 [**Installing Libraries**](#Section31)<br>
#   3.2 [**Upgrading Libraries**](#Section32)<br>
#   3.3 [**Importing Libraries**](#Section33)<br>
# 4. [**Data Acquisition & Description**](#Section4)<br>
# 5. [**Data Pre-Profiling**](#Section5)<br>
# 6. [**Data Pre-Processing**](#Section6)<br>
# 7. [**Data Post-Profiling**](#Section7)<br>
# 8. [**Exploratory Data Analysis**](#Section8)<br>
# 9. [**Summarization**](#Section9)</br>
#   9.1 [**Conclusion**](#Section91)</br>
#   9.2 [**Actionable Insights**](#Section91)</br>
#
# ---

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
# Red wine is made by fermenting dark-colored, whole grapes. It is high in antioxidants, and drinking moderate amounts has been shown to be good for health.Grapes are rich in many antioxidants. These include resveratrol, catechin, epicatechin and proanthocyanidins.
#
# These antioxidants, especially resveratrol and proanthocyanidins, are believed to be responsible for the health benefits of red wine. Proanthocyanidins may reduce oxidative damage in the body. They may also help prevent heart disease and cancer.
# Resveratrol is found in grape skin. It is produced in some plants, as a response to damage or injury.However, the resveratrol content of red wine is rather low. You would have to consume several bottles per day to reach the amount used in the animal studies. This is not recommended, for obvious reasons. If you’re drinking wine just for the resveratrol content, then getting it from a supplement may be a better idea
#
# There seems to be a **J-shaped curve that explains the relationship between wine intake and the risk of heart disease**.
# People who drink approximately 150 ml (5 oz) of red wine a day seem to be at about a 32% lower risk than non-drinkers.
# However, **higher intake increases the risk of heart disease dramatically**.
#
# Drinking **small amounts of red wine** may reduce the risk of heart disease by helping to retain the “good” HDL cholesterol in the blood. Oxidative damage and the oxidation of the “bad” LDL cholesterol may also be reduced by up to 50%
# One study also showed that consuming **2–3 glasses of dealcoholized red wine per day may lower blood pressure**.
#
# Many studies have shown that **moderate wine drinkers are at a lower risk of death from heart disease**, compared to non-drinkers or beer and spirit drinkers.

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
#
# - This section is emphasised on providing some generic introduction to the problem that most companies confronts.
#
#
#   - Wine industry shows a recent growth spurt as social drinking is on the rise.
#
#   - The price of wine depends on a rather abstract concept of wine appreciation by wine tasters.
#
#   - Pricing of wine depends on such a volatile factor to some extent.
#
#   - Another key factor in wine certification and quality assessment is physicochemical tests which are laboratory-based.
#
#   - For the wine market, it would be of interest if human quality of tasting can be related to the chemical properties of wine.
#
#   - Doing so that certification and quality assessment and assurance process is more controlled.
#
#
# <p align="center"><img src="https://raw.githubusercontent.com/insaid2018/Term-2/master/wine%20gif%20term%201%20%26%20Term%202.gif"></p>
#
# - Derive a scenario related to the problem statement and heads on to the journey of exploration.
#
# - **Example Scenario:**
#   - Vintnest, an American Wine Company is pretty famous for it quality of wine.
#
#   - Every three years they try to launch a new wine with additional ingredients.
#
#   - They have all the necessary information accumulated over the past few years.
#
#   - But they are looking for an advanced and effective solution to find out best ingredient is best possible time.
#
#   - To tackle this problem they hired a genius team of data scientists. Consider you are one of them...

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Installing Libraries**

# %%
# !pip install -q datascience                                         
# !pip install -q pandas-profiling                                    

# Library to generate basic statistics about data

# %% [markdown]
# ### **Upgrading Libraries**
#
# - **After upgrading** the libraries, you need to **restart the runtime** to make the libraries in sync.
#
# - Make sure not to execute the cell under Installing Libraries and Upgrading Libraries again after restarting the runtime.

# %%
# !pip install -q --upgrade pandas-profiling

# %% [markdown]
# ### **Importing Libraries**
#
# - You can headstart with the basic libraries as imported inside the cell below.
#
# - If you want to import some additional libraries, feel free to do so.

# %%
#-------------------------------------------------------------------------------------------------------------------------------
import pandas as pd                                                 # Importing package pandas (For Panel Data Analysis)
from pandas_profiling import ProfileReport                          # Import Pandas Profiling (To generate Univariate Analysis)
#-------------------------------------------------------------------------------------------------------------------------------
import numpy as np                                                  # Importing package numpys (For Numerical Python)
#-------------------------------------------------------------------------------------------------------------------------------
import matplotlib.pyplot as plt                                     # Importing pyplot interface to use matplotlib
import seaborn as sns                                               # Importing seaborn library for interactive visualization
# %matplotlib inline
#-------------------------------------------------------------------------------------------------------------------------------
import scipy as sp                                                  # Importing library for scientific calculations
from scipy import stats                                             # Importing stats module for calculating trimmed means
#-------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Data Acquisition & Description**
# ---
#
# -  P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis.
#    Modeling wine preferences by data mining from physicochemical properties.
#    In Decision Support Systems, Elsevier, 47(4):547-553. ISSN: 0167-9236.
#
#    Available at: [@Elsevier] http://dx.doi.org/10.1016/j.dss.2009.05.016
#                 [Pre-press (pdf)] http://www3.dsi.uminho.pt/pcortez/winequality09.pdf
#                 [bib] http://www3.dsi.uminho.pt/pcortez/dss09.bib
#    two datasets were created, using red and white wine samples.
#    The inputs include objective tests (e.g. PH values) and the output is based on sensory data
#    (median of at least 3 evaluations made by wine experts). Each expert graded the wine quality
#    between 0 (very bad) and 10 (very excellent).
#
# - To good idea about the features of the data set, see below:
#
# |Id|Feature|Description|
# |:--|:--|:--|
# |01|fixed acidity g / dm³| most acids involved with wine or fixed or nonvolatile (do not evaporate readily).|
# |02|volatile acidity g / dm³|the amount of acetic acid in wine, which at too high of levels can lead to an unpleasant, vinegar taste.|
# |03|citric acid g / dm³|found in small quantities, citric acid can add ‘freshness’ and flavor to wines.|
# |04|residual sugar g / dm³| the amount of sugar remaining after fermentation stops, it’s rare to find wines with less than 1 gram/liter |
# |||and wines with greater than 45 grams/liter are considered sweet.|
# |05| chlorides g / dm³| the amount of salt in the wine.|
# |06| free sulfur dioxide g / dm³  | free form of SO2 exists in equilibrium between molecular SO2 (as a dissolved gas) and bisulfite ion;|
# |||it prevents microbial growth and the oxidation of wine.|
# |07|  total sulfur dioxide g / dm³ | amount of free and bound forms of S02; in low concentrations, SO2 is mostly undetectable in wine,|
# |||but at free SO2 concentrations over 50 ppm, SO2 becomes evident in the nose and taste of wine|
# |08| density g / cm³| the density of water is close to that of water depending on the percent alcohol and sugar content|
# |09| pH | describes how acidic or basic a wine is on a scale from 0 (very acidic) to 14 (very basic);|
# ||| most wines are between 3-4 on the pH scale.|
# |10| sulphates g / dm³| a wine additive which can contribute to sulfur dioxide gas (S02) levels, wich acts as an antimicrobial and antioxidant.|
# |11| alcohol % by volume| the percent alcohol content of the wine.|
# |12| quality| score between 0 to 10.|

# %%
data = pd.read_csv(filepath_or_buffer = 'https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/winequality.csv')
print('Data Shape:', data.shape)
data.head()
# Out:
# Data Shape: (6497, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# ...

# %% [markdown]
# ### **Data Description**
#
# **Interesting observations**
# - Mean Values of most of the columns are close to the median value of each column, except total sulfur dioxide and residual sugar.
# - There is a large difference between the 75th% tile and max values of residual sugar, free sulfur dioxide & total sulfur dioxide.

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
data.median()
# Out:
# fixed acidity             7.00000
# volatile acidity          0.29000
# citric acid               0.31000
# residual sugar            3.00000
# chlorides                 0.04700
# free sulfur dioxide      29.00000
# total sulfur dioxide    118.00000
# density                   0.99489
# pH                        3.21000
# sulphates                 0.51000
# alcohol                  10.30000
# quality                   6.00000
# dtype: float64

# %% [markdown]
# ### **Data Information**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(data,title="Wine Profiling before Data Preprocessing", progress_bar=False, minimal=True)
profile.to_file(output_file="Wine_profiling_before_preprocessing.html")

# %% [markdown]
# # **OBSERVATIONS**
# Dataset has 1179 (18.1%) duplicate rows
# citric acid has 151 (2.3%) zeros

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#
# - This section is emphasised on performing data manipulation over unstructured data for further processing and analysis.
#
# - To modify unstructured data to strucuted data you need to verify and manipulate the integrity of the data by:
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %%
data.isnull().any().any()  # Missing data if any, None found
                           #data.isnull().sum()
# Out:
# False

# %% [markdown]
# ### * There is no missing data.

# %%
data.drop_duplicates(subset=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides','free sulfur dioxide','total sulfur dioxide', 'density','pH','sulphates','alcohol'], keep = "first", inplace = True, ignore_index=True)          #Remove redundant data or duplicates drop
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
# 5            7.9              0.60         0.06             1.6      0.069
# 6            7.3              0.65         0.00             1.2      0.065
# 7            7.8              0.58         0.02             2.0      0.073
# 8            7.5              0.50         0.36             6.1      0.071
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data.info() #check for number of rows , inconsistencies,typos none found
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5318 entries, 0 to 5317
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         5318 non-null   float64
#  1   volatile acidity      5318 non-null   float64
#  2   citric acid           5318 non-null   float64
#  3   residual sugar        5318 non-null   float64
#  4   chlorides             5318 non-null   float64
#  5   free sulfur dioxide   5318 non-null   float64
#  6   total sulfur dioxide  5318 non-null   float64
#  7   density               5318 non-null   float64
#  8   pH                    5318 non-null   float64
#  9   sulphates             5318 non-null   float64
#  10  alcohol               5318 non-null   float64
#  11  quality               5318 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 498.7 KB

# %% [markdown]
#  * Data has 10 float and 1 integer values

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %%
profile = ProfileReport(data,title="Wine Profiling after Data Preprocessing", progress_bar=False, minimal=True)
profile.to_file(output_file="Wine_profiling_after_preprocessing.html")# Insert your code here...

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# 8.1.1 How many wines have that particular quality rating from 3-9?
# ---
#
# - Quality ratings of wines seems to be starting from 3-9
#
# - Apparently ratings 3 and 9 are given to a smaller number of wines, lets probe further on this to understand what dictates the quality of wines
# - Majority of the chunk of wines seems to be having quality rating of 5 and 6

# %%
data['quality'].value_counts().sort_index(ascending=True).sort_values(ascending=True)
# Out:
# 9       5
# 3      30
# 8     148
# 4     206
# 7     855
# 5    1751
# 6    2323
# Name: quality, dtype: int64

# %% [markdown]
# **Univariate Analysis**
#
# Quality ratings distribution among the sample wines to see how many wines are rated with a specific rating from 3 to 9

# %%
# how many wines have that rating from 1-9 in our dataset
sns.displot(data['quality'],color='g',kde=True)  # Insert your code here...

# %% [markdown]
# # **8.1.2. How Sour are these Wines?**

# %%
data['pH'].plot.hist(color='purple',bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# * These wines are quite sour with pH of 2.8 to 3.8

# %% [markdown]
# # 8.1.3. Alcohol distribution among these wines for body of wine

# %%
from scipy.stats import skewnorm
sns.displot(data['alcohol'],color='red',kde=True)

# %% [markdown]
# **Interpretation**
# * When tasting a wine, you'll notice alcohol comes through as heat in your back of your mouth or throat. Average alcohol content of wines are 10.5% which are considered as **low alcohol wines**.
# * Some wines are having 12.5 to 14% **medium alcohol wines**
# * These will taste slightly warmer and bolder; almost like a slight tingling sensation on your palate.

# %% [markdown]
# # 8.1.4. Are they dry, medium dry, medium in sweetness?
# * Bone-Dry <1 sugar calories per glass
# * Dry 0-6 sugar calories per glass
# * Off-Dry 6–21 sugar calories per glass
# * Sweet 21–72 sugar calories per glass
# * Very Sweet 72–130 sugar calories per glass

# %%
sns.displot(data['residual sugar'],color='blue',kde=True,bins=25)

# %% [markdown]
# # What kind of relationships are driving Quality of wines
# **What is the relationship of residual sugar to denser wines?**
# **Is it Citric acid which is giving freshness to wine?**

# %% [markdown]
# **Bivariate Analyis**
#
# - Citric acid has many uses in wine production. Citric acid is a weak organic acid, which is often used as a natural preservative to a drink to add a sour taste.
#
# - The disadvantage of adding citric acid is its microbial instability. Since bacteria use citric acid in their metabolism, it may increase the growth of unwanted microbes. Often to increase acidity of wine, winemakers will add tartaric acid instead.

# %%
boxplt = sns.boxplot(x='quality',y='citric acid', data=data)
boxplt.set(title="Citric Acid in Different Quality Wines")
# Out:
# [Text(0.5, 1.0, 'Citric Acid in Different Quality Wines')]

# %% [markdown]
# **Interpretation**
# Citric acid is often added to wines to increase acidity, complement a specific flavor or prevent ferric hazes. It can be added to finished wines to increase acidity and give a “fresh” flavor. So we observe that quality rating went up significantly with marginal increase in Citric acid quantity

# %% [markdown]
# # **How does Sulphates and Acetic acid contribute to Quality of wines if at all?**

# %%
boxplt = sns.boxplot(x='quality',y='sulphates', data=data)
boxplt.set(title="Sulphates concentration Vs Quality Wines")
# Out:
# [Text(0.5, 1.0, 'Sulphates concentration Vs Quality Wines')]

# %% [markdown]
# **Interpretation**
# This boxplot shows that higher sulphate contents tend to correspond with lower wine quality.  Sulphates seems to lower the wine quality as it dulls the wine’s fermentation process.

# %%
boxplt = sns.boxplot(x='quality',y='volatile acidity', data=data)
boxplt.set(title="Acetic Acid's influence on the Quality of the Wines")
# Out:
# [Text(0.5, 1.0, "Acetic Acid's influence on the Quality of the Wines")]

# %% [markdown]
# **Interpretation of the box plot**
# Apparently the general trend is that higher the acetic acid, lower is the quality rating. In all wines having quality rating from 6-8, it is observed that some wines also had lower quantity of acetic acid than that of wines in 9. the only explanation is in this case would be it's quality rating probably is dictated by a blend of other parameters as well.

# %% [markdown]
# # **Relationship of Alcohol to wines quality and how is that exploited by wine companies**

# %% [markdown]
# **What-is-the-difference-between-full-bodied-and-light-bodied-wine?**
# - Full bodied wines are defined by their very dark red colour, higher alcohol percentage and high mouth coating density
# - Wines under 12.5% alcohol are said to light-bodied like Vinho Verde.
# - Wines such as Rose, French Burgundy, Pinot Grigio and Sauvignon Blanc between 12.5% and 13.5% are considered medium-bodied  - - finally, wines like Zinfandel, Syrah/Shiraz, Cabernet, Merlot and Malbec over 13.5% alcohol is considered full-bodied.

# %%
# Using seaborn's violinplot function to draw a violin plot between High_Or_Low_Sugar and Serve_Size columns.

plt.figure(figsize=(10,6))
sns.violinplot(data=data, x='quality', y='alcohol', palette="magma", linewidth = 2)

plt.title('Violin plot showing the variation of quality on the basis of alcohol')
# Out:
# Text(0.5, 1.0, 'Violin plot showing the variation of quality on the basis of alcohol')

# %% [markdown]
# **Interpretation**
# * This violin plot shows the rating of wines on the basis of low to High alcohol within a quality rank. Few important observations are:
# * We can see relatively high variance is observed in rating 3 wines.
# * Rating 5 wines are positively skewed, while rating 7 wines are showing bimodality with 8 rated wines are showing negative skew.
# * The items having **high alcohol content have high quality** when compared to items having low alcohol content.

# %% [markdown]
# # **Is the wine softer ? Fixed acidity Vs pH is usual or higher?**

# %%
data.plot(kind='hexbin', x='fixed acidity', y='pH', figsize=(12, 6), gridsize=20, fontsize=15, colormap='YlGn')

plt.title('Hexplot showing the variation of fixed acidity with pH')
# Out:
# Text(0.5, 1.0, 'Hexplot showing the variation of fixed acidity with pH')

# %% [markdown]
#  * The predominant fixed acids found in wines are tartaric, malic, citric, and succinic.  Their respective levels found in wine can vary greatly but in general one would expect to see 1,000 to 4,000 mg/L tartaric acid, 0 to 8,000 mg/L malic acid, 0 to 500 mg/L citric acid, and 500 to 2,000 mg/L succinic acid.
#  * All of these acids originate in grapes with the exception of succinic acid, which is produced by yeast during the fermentation process.  Grapes also contain ascorbic acid (Vitamin C), but this is lost during fermentation.  It is also legal to add fumaric acid as a preservative.
#  * The hexplot showed that the most of number of wines had **fixed acidity in the ranges of 4 to 9** , In olden days, pH beyond 3.6 is rare. Currently winemakers in California  are pushing wines to high pH levels, as high as 4.0, which makes the wines softer.

# %% [markdown]
# # Is there a relationship to quality of wines and sulfur dioxide content?

# %%
# Using pandas plot function to plot the stacked bar chart for the free sulfur dioxide, total sulfur dioxide 
# Using the kind='bar' to plot a bar chart.
# This chart shows the amount of free sulfur dioxide with respect to the Total sulfur dioxide .

data.groupby(['quality'])['total sulfur dioxide'].mean().plot(kind='bar', figsize=(10, 5), color='grey')
data.groupby(['quality'])['free sulfur dioxide'].mean().plot(kind='bar', figsize=(10, 5), color='green')


plt.xlabel('qualityy')
plt.ylabel('Sulfur dioxide Content')
plt.title('Stacked Bar Chart showing the sulfur dioxide content of each quality rated wine')
plt.legend(labels=('Total sulfur dioxide', 'free sulfur dioxide'))

# %% [markdown]
# **Interpretation**
# - The higest correlation, 0,72, is seen between total and free sulfur dioxide, which is expected
# - However, stacked plot of **free sulfur dioxide and total sulfur dioxide to quality of wines shows no correlation** what so ever

# %% [markdown]
# **Multivariate Analysis**
# * Density is important physico chemical property of wines; how are the presence of chlorides, fixed acids, residual sugar and alcohols influence density,and how do they dictate quality of wines.
#
# * Correlation values between quality and the other features are to be explored for indepth knowledge.
# * Correlation matrix gives a better understanding of how features correlate with each other.

# %%
# Using seaborn's pairplot function to plot the pairplot for specific columns of the dataset with hue as ranks.

sns.pairplot(data, vars = ['density', 'residual sugar', 'chlorides', 'fixed acidity', 'alcohol'], dropna = True, hue = 'quality',palette='rainbow_r')

# %% [markdown]
# **Interesting to note that residual sugar seems highly correlated to density.**
# * Also fixed acidity is having positive correlation to density as mixture of acids exist due to fermentation.
# * Density has **high negative correlation** to alcohol.
# * Chlorides are also influencing density **due to salty water irrigation of grapes**

# %% [markdown]
# # Heatmap to understand the correlations between quality ratings and parameters

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(), annot=True,cmap="PiYG", fmt=".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Interpretation**
# - Strong Negative correlation between density and alcohol followed by residual sugar and chlorides.
# - This implies that, as **any one of the above variables increases, the alcohol decreases.**
# - Strong Positive correlations between the alcohol and quality, residual sugar, and density.
# - Lower sulphate levels in wines with high quality ratings, but the higest are found in the medium quality
# - **Lower levels of volatile acids** in wines with high quality ratings

# %% [markdown]
# ---
# <a name = Section9></a>
# # **9. Summarization**
# ---

# %% [markdown]
# <a name = Section91></a>
# ### **9.1 Conclusion**
#
# - Using Exploratory data analysis we understood the variable distribution patterns in all wines taken for sensory studies to make quality rating excercise
# - The features are understood using univariate,bivariate and multivariate analysis

# %% [markdown]
# <a name = Section92></a>
# ### **9.2 Actionable Insights**
#
# - Quality rating of wines seems to be mainly dependent on the alcohol content , higher the alcohol , ratings are higher.
# - Ratings also increase with slight increase of citric acid, due to freshness it provides
# - Wineries needs to avoid the use of salt water for grapes irrigation, as it increase cholrides which inturn increase the density of wines , bringing down the quality rating
